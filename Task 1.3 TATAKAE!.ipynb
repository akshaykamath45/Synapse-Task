# %%
class Titandex():
    
    def __init__(self,name,height,strength,ws=0):
        self.name=name#name of initialized titan
        self.height=height
        self.strength=strength#strength of initialized titan
        self.ws=ws
        
             
    def TitanvsScout(self):
        i=0
        n=int(input("Enter the number of battles:"))
        while i<n:
            
            self.names=str(input("Enter the name of the scout : \n"))#names for name of scout
            self.strengths=int(input("Enter the strength of the scout :\n"))#strengths for strength of scout
            self.ws=0
            
            
            if(t1.strength>self.strengths):
                print("Titan won")
                i+=1
                self.ws+=i
                print("Winning streak for titan is :"+str(self.ws))
                     

            elif(t1.strength==self.strengths):
                print("Draw")
                self.ws=0
                print("Winning streak for titan reseted to :"+str(self.ws))
                i=0
              

            else:
                print("Scout Won")
                self.ws=0
                print("Winning streak for titan reseted to :"+str(self.ws))
                i=0
                

    def TitanvsTitan(self):
        self.namet=str(input("Enter the name of the Titan : \n"))#name of titan
        self.strengtht=int(input("Enter the strength of the Titan :\n"))#strength of titan
        if(t1.name==self.namet):
            print("Titans Cannot Fight amongst Itself")
            
        elif(t1.strength>self.strengtht):  
            print(t1.name+" Won")
                   
        elif(t1.strength==self.strengtht):
            print("Draw")             

        else:  
            print(self.namet+" Won")
                    
        
        
t1=Titandex("Founding Titan",12,350)
t1.TitanvsScout()
t1.TitanvsTitan()
# Out:
# Enter the number of battles:3
# Enter the name of the scout :
# Levi
# Enter the strength of the scout :
# 300
# Titan won
# Winning streak for titan is :1
# Enter the name of the scout :
# Mikasa
# Enter the strength of the scout :
# 400
# Scout Won
# Winning streak for titan reseted to :0
# Enter the name of the scout :
# Eren
# Enter the strength of the scout :
# 270
# Titan won
# Winning streak for titan is :1
# Enter the name of the scout :
# Armin
# Enter the strength of the scout :
# 250
# Titan won
# Winning streak for titan is :2
# Enter the name of the scout :
# Erwin
# Enter the strength of the scout :
# 275
# Titan won
# Winning streak for titan is :3
# Enter the name of the Titan :
# Founding Titan
# Enter the strength of the Titan :
# 350
# Titans Cannot Fight amongst Itself
